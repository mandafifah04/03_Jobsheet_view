# %% [markdown]
# <a href="https://colab.research.google.com/github/mandafifah04/03_Jobsheet_view/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
pais=cv.imread('/content/drive/MyDrive/PCVK/kitten.jpeg')
plt.imshow(pais)

# %%
pais2=pais
pais3=cv.cvtColor(pais,cv.COLOR_BGR2RGB)
plt.imshow(pais3)

# %%
pais_gray=cv.imread('/content/drive/MyDrive/PCVK/kitten.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(pais_gray)

# %%
plt.imshow(pais_gray, cmap='gray')

# %%
plt.imshow(pais_gray, cmap='magma')

# %%
pais4=cv.resize(cv.cvtColor(pais,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(pais4)

# %%
pais5=cv.flip(cv.cvtColor(pais,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ex  = fig.add_subplot(111)
ex.imshow(pais5)

# %%
black_pais = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_pais)

# %%
cv.rectangle(black_pais,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=5)
plt.imshow(black_pais)

# %%
cv.rectangle(black_pais,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=10)
plt.imshow(black_pais)

# %%
cv.circle(black_pais,center=(100,100),radius=50,color=(255,0,0),thickness=5)
plt.imshow(black_pais)

# %%
cv.line(black_pais,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_pais)

# %%
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_pais,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(black_pais)

# %%
black_pais2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_pais2)

# %%
vertices=np.array([[100,300],
                   [200,200],
                   [400,300],
                   [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape((-1,1,2))#fungsi reshape adalah mengubah bentuk array tanpa mengubah data
pts#dimana pada kasus ini data data akan dibentuk menjadi per kolom menambahkan kurung siku
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_pais2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_pais2)

# %%
#Tugas No 1

# %%
#Tugas No 2
plt.imshow(pais_gray,cmap='RdYlGn')

# %%
plt.imshow(pais_gray,cmap='GnBu')

# %%
#Tugas No 3
#Tampilkan image baris ke 20-115, kolom 25-120!
plt.imshow(pais3)

# %%
plt.imshow(pais3[20:115,25:120])

# %%
#Tugas No 4
#Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
plt.imshow(pais_gray,cmap='Blues')

# %%
plt.imshow(pais_gray[5:30])

# %%
#Tugas No 5
#Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.disarankan menggunakan bilangan acak/random!
t=pais.shape[0]
l=pais.shape[1]
print("t = ",t,"l = ",l)
# Out:
# t =  213 l =  237

# %%
pais10=cv.imread('/content/drive/MyDrive/PCVK/kucing.jpeg')
paisK5=pais10
for r in range(5):
  start=np.random.randint(0,213)
  end=np.random.randint(0,237)
  r=np.random.randint(0,255)
  g=np.random.randint(0,255)
  b=np.random.randint(0,255)
  color=(r,g,b)
  startp=(start,start)
  endp=(end,end)
  thickness = 5
  paisK5=cv.rectangle(paisK5,startp,endp,color,thickness)
plt.imshow(paisK5)

# %%
#Tugas No 6
#Tampilkan image dengan posisi terbalik!
paisK5=cv.flip(paisK5,0)
plt.imshow(paisK5)

# %%
#Tugas No 7 
#Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).
pais11=cv.imread('/content/drive/MyDrive/PCVK/pais.jpeg')
t=pais11.shape[0]
l=pais11.shape[1]
print("t = ",t,"l = ",l)
# Out:
# t =  768 l =  768

# %%
pais11=cv.imread('/content/drive/MyDrive/PCVK/pais.jpeg')
pais12=pais11
pais13=cv.cvtColor(pais11,cv.COLOR_BGR2RGB)
plt.imshow(pais13)

# %%
paisK8=pais11
cv.rectangle(paisK8,(500,400),(250,150),color=(24, 56, 164),thickness=5)
cv.circle(paisK8,center=(400,150),radius=100,color=(255,0,0),thickness=2)
plt.imshow(paisK8)

# %%
# Tugas No 8
#Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
pais12 = cv.cvtColor(pais11, cv.COLOR_BGR2RGB)
cv.rectangle(pais12,pt1=(0,300), pt2=(100,pais12.shape[1]), color=(255,255,255), thickness=5)
R,G,B = cv.split(pais12)
zeros = np.zeros(pais12.shape[:2], dtype="uint8")
blue = cv.merge([zeros,zeros,B])
plt.imshow(blue)

# %%
# Tugas No 9
# Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(pais13,text='pais ganteng',org=(10,700),fontFace=font,fontScale=4,color=(90,187,20),thickness=5,lineType=cv.LINE_AA)
plt.imshow(pais13)
